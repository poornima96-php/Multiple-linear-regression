# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r'C:\Users\poorn\OneDrive\Documents\ExcelR\Asssignment\Assign_5\50_startups.csv')
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# EDA

# %%
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
dataset.shape
# Out:
# (50, 5)

# %%
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
dataset=dataset.rename({'R&D Spend':'RD','Administration': 'ADMIN', 'Marketing Spend':'Spend'}, axis=1)
dataset.head()
# Out:
#           RD      ADMIN      Spend       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RD      50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   Spend   50 non-null     float64
#  3   State   50 non-null     object
#  4   Profit  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.3+ KB

# %%
dataset.State=dataset.State.astype('category')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RD      50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   Spend   50 non-null     float64
#  3   State   50 non-null     category
#  4   Profit  50 non-null     float64
# dtypes: category(1), float64(4)
# memory usage: 2.1 KB

# %%
dataset.isnull().any().any()
# Out:
# False

# %%
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# Correlation

# %%
dataset.corr()
# Out:
# C:\Users\poorn\AppData\Local\Temp\ipykernel_19560\2191645083.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#               RD     ADMIN     Spend    Profit
# RD      1.000000  0.241955  0.724248  0.972900
# ADMIN   0.241955  1.000000 -0.032154  0.200717
# Spend   0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %% [markdown]
# Data Visualization
# scatterplot between variables along with histograms

# %%
import seaborn as sns

# %%
sns.displot(dataset['RD'])

# %%
sns.pairplot(dataset)
plt.show()

# %%
vis1 = sns.lmplot(data = dataset, x = 'RD', y = 'ADMIN',fit_reg = False, hue = 'State') #lm - linear model
vis1

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols("Profit~RD+ADMIN+Spend", data= dataset).fit()

# %%
model

# %% [markdown]
# Testing

# %%
# coffiecient
model.params
# Out:
# Intercept    50122.192990
# RD               0.805715
# ADMIN           -0.026816
# Spend            0.027228
# dtype: float64

# %%
#t and p-Values
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept     7.626218
# RD           17.846374
# ADMIN        -0.525507
# Spend         1.655077
# dtype: float64
#  Intercept    1.057379e-09
# RD           2.634968e-22
# ADMIN        6.017551e-01
# Spend        1.047168e-01
# dtype: float64

# %%
#R squared values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %% [markdown]
#  Build SLR and MLR models

# %%
slr_A=smf.ols("Profit~ADMIN",data=dataset).fit()
slr_A.tvalues , slr_A.pvalues
# Out:
# (Intercept    3.040044
#  ADMIN        1.419493
#  dtype: float64,
#  Intercept    0.003824
#  ADMIN        0.162217
#  dtype: float64)

# %%
slr_S=smf.ols("Profit~Spend",data=dataset).fit()
slr_S.tvalues , slr_S.pvalues
# Out:
# (Intercept    7.808356
#  Spend        7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  Spend        4.381073e-10
#  dtype: float64)

# %%
#spend has significant p values where as admin has insignificat p value

# %%
mlr = smf.ols("Profit~ADMIN+Spend",data=dataset).fit()
mlr.tvalues,mlr.pvalues
# Out:
# (Intercept    1.142741
#  ADMIN        2.467779
#  Spend        8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  ADMIN        1.729198e-02
#  Spend        9.727245e-11
#  dtype: float64)

# %%
# model has sufficient p values

# %% [markdown]
# VIF

# %%
rsq_R=smf.ols("RD~ADMIN+Spend",data=dataset).fit().rsquared
vif_R=1/(1-rsq_R)
vif_R
# Out:
# 2.468903069994701

# %%
rsq_A=smf.ols("ADMIN~RD+Spend",data=dataset).fit().rsquared
vif_A=1/(1-rsq_A)
vif_A
# Out:
# 1.175091007055045

# %%
rsq_S=smf.ols("Spend~ADMIN+RD",data=dataset).fit().rsquared
vif_S=1/(1-rsq_S)
vif_S
# Out:
# 2.3267732905308773

# %%
# Storing vif values in a data frame
data={'Variables':['RD','ADMIN','Spend'],'Vif':[vif_R,vif_A,vif_S]}

# %%
Vif_df=pd.DataFrame(data)
Vif_df
# Out:
#   Variables       Vif
# 0        RD  2.468903
# 1     ADMIN  1.175091
# 2     Spend  2.326773

# %% [markdown]
# residual analysis
# Test for Normality of Residuals (Q-Q Plot)

# %%
import statsmodels.api as sm

# %%
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49], dtype=int64)]

# %% [markdown]
# #residuals plots for homoscedasticity

# %%
#residuals plots for homoscedasticity
def get_standard_values(vals) :
    return (vals-vals.mean())/vals.std()

# %%
plt.scatter(get_standard_values(model.fittedvalues),get_standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %% [markdown]
# Residual vs regressors

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model,"RD",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'ADMIN',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Spend',fig=fig)
plt.show()

# %% [markdown]
# Model Deletion Diagnostics
# (Detecting Outliers or Influencers)
# #cook's distance

# %%
#Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
#plot the influence values using stem plot
fig=plt.figure(figsize=(18,5))
plt.stem(np.arange(len(dataset)),np.round(c,5))
plt.xlabel('Rows Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))
# Out:
# (49, 0.2880822927543267)

# %% [markdown]
# High Influence plot

# %%
from statsmodels.graphics.regressionplots import influence_plot

# %%
influence_plot(model)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=dataset.shape[1]
n=dataset.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
dataset[dataset.index.isin([49])]
# Out:
#      RD     ADMIN     Spend       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
# Discard the data points which are influencers and re-assign the row number (reset_index(drop=True))
dataset1=dataset.drop(dataset.index[[49]],axis=0).reset_index(drop=True)
dataset1
# Out:
#            RD      ADMIN      Spend       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# build model

# %%
model2=smf.ols("Profit~RD+ADMIN+Spend",data=dataset1).fit()

# %%
while model2.rsquared < 0.99:
    for c in [np.max(c)>1]:
        model2=smf.ols("Profit~RD+ADMIN+Spend",data=dataset1).fit()
        (c,_)=model2.get_influence().cooks_distance
        c
        np.argmax(c) , np.max(c)
        dataset1=dataset1.drop(dataset1.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
        df1
    else:
        final_model=smf.ols("Profit~RD+ADMIN+Spend",data=dataset1).fit()
        final_model.rsquared , final_model.aic
        print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9626766170294073
# Thus model accuracy is improved to 0.9614129113440602
# Thus model accuracy is improved to 0.962593650298269
# Thus model accuracy is improved to 0.9638487279209415
# Thus model accuracy is improved to 0.9663901957918795
# Thus model accuracy is improved to 0.9706076169779905
# Thus model accuracy is improved to 0.9727840588916423
# Thus model accuracy is improved to 0.9734292907181952
# Thus model accuracy is improved to 0.9785801571833451
# Thus model accuracy is improved to 0.9777383743090916
# Thus model accuracy is improved to 0.9790510088977512
# Thus model accuracy is improved to 0.9790004461890552
# Thus model accuracy is improved to 0.9807878666153609
# Thus model accuracy is improved to 0.9838299343609735
# Thus model accuracy is improved to 0.983114992639277
# Thus model accuracy is improved to 0.9833768520972176
# Thus model accuracy is improved to 0.9878892536376698
# ...

# %% [markdown]
# New Model Predictions

# %%
#Let New data for prediction is
new_data=pd.DataFrame({'RD':55000,"ADMIN":60000,"Spend":100000},index=[0])
new_data
# Out:
#       RD  ADMIN   Spend
# 0  55000  60000  100000

# %%
# Manual Predictions of Price
final_model.predict(new_data)
# Out:
# 0    91796.559004
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy
pred_y=final_model.predict(dataset1)
pred_y
# Out:
# 0     165589.539700
# 1     158552.826483
# 2     156789.000710
# 3     149524.698853
# 4     150122.356712
# 5     126598.769555
# 6     130104.785747
# 7     127878.387928
# 8     117298.757074
# 9     111329.242429
# 10    110009.916133
# 11    102331.717613
# 12    109661.804131
# 13    103462.767086
# 14    101874.612012
# 15     97655.794577
# 16     97872.919535
# 17     96858.382686
# 18     98654.449007
# 19     93583.600868
# 20     91186.568204
# 21     88571.938968
# 22     84521.312916
# 23     78528.002935
# 24     76670.262623
# 25     73237.524757
# 26     68075.710756
# dtype: float64

# %% [markdown]
# R^2 value for each prepared model

# %%
Each_d={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(Each_d)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.988276
